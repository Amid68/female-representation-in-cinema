# %% [markdown]
# # Female Representation in Cinema
#
# Time: 45 Minutes
# - TODO: Download the movies.csv file manually using the following link, upload it to your
# workspace, read it using pandas, and assess, and clean as many as issues you can.
# - Dataset Link:
# https: //www.kaggle.com/datasets/vinifm/female-representation-in-cinema?select=movies.csv
# - Save cleaned dataset/datasets.
# - For Present The Cleaned Dataset/Datasets: Please choose one of you to talk about the group and present the final dataset/datasets after cleaning.

# %%
import pandas as pd

# %%
movies_df = pd.read_csv('archive/movies.csv')
oscar_df = pd.read_csv('archive/oscar.csv')

# %%
movies_df.shape
# Out:
# (7279, 22)

# %%
pd.set_option('display.max_columns', None)
movies_df.head()
# Out:
#    Unnamed: 0                      title  year  bt_score  dubious  imdbid  \
# 0           0                 Cinderella  1899         3        0     230
# 1           1     Gretchen the Greenhorn  1916         3        0    6745
# 2           2                 Snow White  1916         3        0    7361
# 3           3  The Poor Little Rich Girl  1917         3        0    8443
# 4           4               Stella Maris  1918         3        0    9652
#
#    tmdbId                                     genres  popularity  \
# 0  114108  ['Drama', 'Family', 'Fantasy', 'Romance']       3.762
# 1  126925                                         []       1.942
# 2  174598                       ['Fantasy', 'Drama']       0.817
# 3   95866  ['Romance', 'Comedy', 'Drama', 'Fantasy']       2.023
# 4   70753                                  ['Drama']       1.310
#
#                 production_companies          production_countries  \
# 0    ['Star-Film', 'Georges Méliès']                    ['France']
# 1                                 []                            []
# 2                                 []                            []
# 3  ['Artcraft Pictures Corporation']  ['United States of America']
# 4          ['Mary Pickford Company']  ['United States of America']
#
#   release_date    revenue  vote_average  vote_count  \
# 0   01/10/1899        0.0           6.1        79.0
# 1   03/09/1916        0.0           6.1         7.0
# 2   24/12/1916        0.0           5.7         9.0
# 3   05/03/1917        0.0           5.8        23.0
# 4   21/01/1918  2400000.0           6.9        19.0
#
#                                                 cast  \
# 0  [{'adult': False, 'gender': 2, 'id': 11523, 'k...
# 1  [{'adult': False, 'gender': 1, 'id': 30779, 'k...
# 2  [{'adult': False, 'gender': 0, 'id': 1658947, ...
# 3  [{'adult': False, 'gender': 1, 'id': 100047, '...
# 4  [{'adult': False, 'gender': 1, 'id': 100047, '...
#
#                                                 crew  budget  \
# 0  [{'adult': False, 'gender': 2, 'id': 11523, 'k...     0.0
# 1  [{'adult': False, 'gender': 2, 'id': 42060, 'k...     0.0
# 2  [{'adult': False, 'gender': 2, 'id': 28968, 'k...     0.0
# 3  [{'adult': False, 'gender': 2, 'id': 13335, 'k...     0.0
# 4  [{'adult': False, 'gender': 1, 'id': 34741, 'k...     0.0
#
#                                cast_gender            crew_gender  \
# 0                       [2, 0, 1, 0, 1, 0]           [2, 2, 2, 2]
# 1                             [1, 2, 2, 2]              [2, 2, 2]
# 2                          [0, 1, 2, 2, 0]                    [2]
# 3  [1, 0, 0, 0, 2, 0, 1, 1, 0, 2, 0, 1, 1]  [2, 2, 1, 1, 2, 2, 0]
# 4                 [1, 1, 2, 2, 1, 0, 0, 2]     [1, 2, 2, 0, 2, 2]
#
#    cast_female_representation  crew_female_representation
# 0                   33.333333                    0.000000
# 1                   25.000000                    0.000000
# 2                   20.000000                    0.000000
# 3                   38.461538                   28.571429
# 4                   37.500000                   16.666667

# %%
movies_df['cast'].head()[0]
# Out:
# '[{\'adult\': False, \'gender\': 2, \'id\': 11523, \'known_for_department\': \'Directing\', \'name\': \'Georges Méliès\', \'original_name\': \'Georges Méliès\', \'popularity\': 3.69, \'profile_path\': \'/9j4HSBt5bmPUhHd9rn7ZeXnf6QW.jpg\', \'cast_id\': 3, \'character\': "Le Gnome de la Pendule / Le Suisse à l\'Entrée de l\'Église", \'credit_id\': \'52fe4b45c3a36847f81fb5d5\', \'order\': 0}, {\'adult\': False, \'gender\': 0, \'id\': 1431399, \'known_for_department\': \'Acting\', \'name\': \'Barral\', \'original_name\': \'Barral\', \'popularity\': 0.6, \'profile_path\': None, \'cast_id\': 4, \'character\': \'Cinderella\', \'credit_id\': \'54ed0a94925141796800285d\', \'order\': 1}, {\'adult\': False, \'gender\': 1, \'id\': 11645, \'known_for_department\': \'Acting\', \'name\': \'Bleuette Bernon\', \'original_name\': \'Bleuette Bernon\', \'popularity\': 1.422, \'profile_path\': \'/u14pGZRIO0Ylsnm9tyimI6I5gbO.jpg\', \'cast_id\': 5, \'character\': \'The Fairy Godmother\', \'credit_id\': \'54ed0a98c3a3686d5600288d\', \'order\': 2}, {\'adult\': False, \'gender\': 0, \'id\': 1431400, \'known_for_department\': \'Acting\', \'name\': \'Carmelli\', \'original_name\': \'Carmelli\', \'popularity\': 0.986, \'profile_path\': None, \'cast_id\': 6, \'character\': \'Prince Charming (as Carmely)\', \'credit_id\': \'54ed0aa4c3a368402d000425\', \'order\': 3}, {\'adult\': False, \'gender\': 1, \'id\': 28964, \'known_for_department\': \'Acting\', \'name\': "Jehanne d\'Alcy", \'original_name\': "Jehanne d\'Alcy", \'popularity\': 0.982, \'profile_path\': \'/j2LBrYmGeNBQQYTE5SWpTSzVCBW.jpg\', \'cast_id\': 8, \'character\': "Fairy Godmother (as Jeanne d\'Alcy)", \'credit_id\': \'54ed0ad9c3a368402d00042b\', \'order\': 5}, {\'adult\': False, \'gender\': 0, \'id\': 1431402, \'known_for_department\': \'Acting\', \'name\': \'Dupeyron\', \'original_name\': \'Dupeyron\', \'popularity\': 1.38, \'profile_path\': None, \'cast_id\': 9, \'character\': \'Party Guest (as Depeyrou)\', \'credit_id\': \'54ed0aeac3a3686d64002d5e\', \'order\': 6}]'

# %% [markdown]
# ## issues
# - delete the unnamed column
# - [] should be considered null value (in the genre, production_companies, and production countries columns)
# - cast and crew columns should be parsed into new dfs
# - there is a separate column for gender so we may choose to delete gender from the movie table
# - 0.0 should be considered null value in revenue, budget columns

# %%
movies_df.tail()
# Out:
#       Unnamed: 0                                title  year  bt_score  \
# 7274        7630                          Sand Castle  2017         0
# 7275        7631  Diary of a Wimpy Kid: The Long Haul  2017         0
# 7276        7632                    God's Own Country  2017         0
# 7277        7633                                 MFKZ  2017         0
# 7278        7634                          War Machine  2017         0
#
#       dubious   imdbid  tmdbId  \
# 7274        0  2582576  390054
# 7275        0  6003368  417830
# 7276        0  5635086  428493
# 7277        0  4717402  461615
# 7278        0  4758646  354287
#
#                                                  genres  popularity  \
# 7274                         ['War', 'Action', 'Drama']      31.004
# 7275                               ['Comedy', 'Family']      17.122
# 7276                               ['Romance', 'Drama']      16.294
# 7277  ['Science Fiction', 'Animation', 'Action', 'Cr...       7.712
# 7278                         ['Comedy', 'Drama', 'War']      12.251
#
#                                    production_companies  ...     revenue  \
# 7274  ['The Mark Gordon Company', 'International Tra...  ...         0.0
# 7275  ['20th Century Fox', 'TSG Entertainment', 'Col...  ...  40120144.0
# 7276  ['BFI', 'Inflammable Films', 'Met Film Product...  ...   2559939.0
# 7277                           ['Ankama', 'Studio 4°C']  ...    461724.0
# 7278                           ['Plan B Entertainment']  ...         0.0
#
#      vote_average  vote_count  \
# 7274          6.5       631.0
# 7275          5.3       355.0
# 7276          7.8       715.0
# 7277          7.1       222.0
# 7278          5.5       922.0
#
#                                                    cast  \
# 7274  [{'adult': False, 'gender': 2, 'id': 130253, '...
# 7275  [{'adult': False, 'gender': 2, 'id': 1517834, ...
# 7276  [{'adult': False, 'gender': 2, 'id': 1206334, ...
# 7277  [{'adult': False, 'gender': 2, 'id': 1265647, ...
# 7278  [{'adult': False, 'gender': 2, 'id': 287, 'kno...
#
#                                                    crew      budget  \
# 7274  [{'adult': False, 'gender': 1, 'id': 5914, 'kn...         0.0
# 7275  [{'adult': False, 'gender': 2, 'id': 1999, 'kn...  22000000.0
# 7276  [{'adult': False, 'gender': 1, 'id': 2635, 'kn...         0.0
# 7277  [{'adult': False, 'gender': 1, 'id': 90162, 'k...         0.0
# 7278  [{'adult': False, 'gender': 2, 'id': 120, 'kno...  60000000.0
#
#                                             cast_gender  \
# 7274  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, ...
# 7275  [2, 1, 2, 2, 2, 2, 2, 2, 2, 1, 1, 0, 0, 0, 1, ...
# 7276         [2, 1, 2, 2, 2, 1, 2, 0, 0, 1, 2, 0, 2, 1]
# 7277      [2, 2, 2, 2, 1, 2, 2, 0, 2, 2, 0, 2, 0, 0, 2]
# 7278  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, ...
#
#                                             crew_gender  \
# 7274  [1, 2, 2, 2, 2, 1, 1, 0, 0, 0, 2, 0, 2, 0, 2, ...
# 7275  [2, 0, 2, 2, 2, 2, 2, 2, 2, 1, 1, 2, 2, 2, 1, ...
# 7276  [1, 2, 0, 2, 2, 2, 2, 1, 0, 0, 0, 1, 2, 0, 0, ...
# 7277               [1, 2, 0, 0, 0, 2, 2, 2, 0, 1, 0, 0]
# 7278  [2, 2, 1, 0, 2, 2, 1, 1, 2, 2, 2, 2, 0, 0, 0, ...
#
#      cast_female_representation crew_female_representation
# 7274                   4.545455                  11.111111
# 7275                  20.289855                  12.000000
# 7276                  28.571429                  10.769231
# 7277                   6.666667                  16.666667
# 7278                  12.280702                  16.129032
#
# [5 rows x 22 columns]

# %%
movies_df.sample(5)
# Out:
#       Unnamed: 0                              title  year  bt_score  dubious  \
# 1059        1086                   The Cutting Edge  1992         3        1
# 7083        7438          The Spiderwick Chronicles  2008         0        0
# 3421        3607                          Smart Ass  2014         3        0
# 5180        5403                      Dead & Buried  1981         1        0
# 5607        5866  Final Fantasy: The Spirits Within  2001         1        0
#
#        imdbid  tmdbId                                             genres  \
# 1059   104040   16562                     ['Comedy', 'Drama', 'Romance']
# 7083   416236    8204        ['Family', 'Adventure', 'Fantasy', 'Drama']
# 3421  2536428  253687                                ['Comedy', 'Drama']
# 5180    82242   24274                              ['Horror', 'Mystery']
# 5607   173840    2114  ['Adventure', 'Action', 'Fantasy', 'Science Fi...
#
#       popularity                               production_companies  \
# 1059       9.878  ['Interscope Communications', 'Metro-Goldwyn-M...
# 7083      35.194      ['Paramount', 'The Kennedy/Marshall Company']
# 3421       6.445                     ['Wild Bunch', 'Stone Angels']
# 5180       7.020         ['Barclays Mercantile Industrial Finance']
# 5607      15.338  ['Chris Lee Productions', 'Square Pictures', '...
#
#                        production_countries release_date      revenue  \
# 1059           ['United States of America']   27/03/1992   25105517.0
# 7083           ['United States of America']   14/02/2008  164170327.0
# 3421                             ['France']   02/04/2014          0.0
# 5180           ['United States of America']   29/05/1981     216166.0
# 5607  ['Japan', 'United States of America']   02/07/2001   85131830.0
#
#       vote_average  vote_count  \
# 1059           7.2       254.0
# 7083           6.6      2171.0
# 3421           6.1       259.0
# 5180           6.4       193.0
# 5607           6.2      1194.0
#
#                                                    cast  \
# 1059  [{'adult': False, 'gender': 2, 'id': 61962, 'k...
# 7083  [{'adult': False, 'gender': 1, 'id': 33397, 'k...
# 3421  [{'adult': False, 'gender': 2, 'id': 1334021, ...
# 5180  [{'adult': False, 'gender': 2, 'id': 24685, 'k...
# 5607  [{'adult': False, 'gender': 1, 'id': 21702, 'k...
#
#                                                    crew       budget  \
# 1059  [{'adult': False, 'gender': 1, 'id': 599, 'kno...          0.0
# 7083  [{'adult': False, 'gender': 2, 'id': 8376, 'kn...   90000000.0
# 3421  [{'adult': False, 'gender': 0, 'id': 129879, '...          0.0
# 5180  [{'adult': False, 'gender': 2, 'id': 1590, 'kn...    3000000.0
# 5607  [{'adult': False, 'gender': 0, 'id': 3504, 'kn...  137000000.0
#
#                                             cast_gender  \
# 1059  [2, 1, 2, 2, 2, 0, 0, 2, 0, 0, 1, 2, 2, 0, 1, ...
# 7083  [1, 1, 1, 2, 2, 1, 2, 1, 2, 2, 2, 2, 1, 0, 0, ...
# 3421         [2, 1, 2, 0, 1, 0, 1, 2, 2, 2, 1, 2, 1, 0]
# 5180  [2, 1, 2, 2, 1, 1, 2, 2, 2, 2, 0, 2, 1, 1, 2, ...
# 5607  [1, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 2, 2, 2, 1, ...
#
#                                             crew_gender  \
# 1059               [1, 2, 2, 2, 2, 2, 2, 2, 2, 0, 0, 0]
# 7083  [2, 2, 2, 1, 1, 2, 2, 2, 1, 2, 0, 2, 2, 2, 0, ...
# 3421                                          [0, 0, 2]
# 5180  [2, 2, 2, 2, 2, 2, 1, 0, 2, 2, 2, 0, 1, 0, 2, ...
# 5607  [0, 2, 2, 1, 0, 0, 2, 0, 2, 2, 2, 2, 0, 1, 2, ...
#
#       cast_female_representation  crew_female_representation
# 1059                   21.052632                    8.333333
# 7083                   35.294118                   17.592593
# 3421                   35.714286                    0.000000
# 5180                   37.931034                    8.333333
# 5607                   27.272727                   12.765957

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7279 entries, 0 to 7278
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  7279 non-null   int64
#  1   title                       7279 non-null   object
#  2   year                        7279 non-null   int64
#  3   bt_score                    7279 non-null   int64
#  4   dubious                     7279 non-null   int64
#  5   imdbid                      7279 non-null   int64
#  6   tmdbId                      7279 non-null   int64
#  7   genres                      7279 non-null   object
#  8   popularity                  7279 non-null   float64
#  9   production_companies        7279 non-null   object
#  10  production_countries        7279 non-null   object
#  11  release_date                7279 non-null   object
#  12  revenue                     7279 non-null   float64
#  13  vote_average                7279 non-null   float64
#  14  vote_count                  7279 non-null   float64
#  15  cast                        7279 non-null   object
#  16  crew                        7279 non-null   object
#  17  budget                      7279 non-null   float64
#  18  cast_gender                 7279 non-null   object
#  19  crew_gender                 7279 non-null   object
#  20  cast_female_representation  7279 non-null   float64
#  21  crew_female_representation  7279 non-null   float64
# dtypes: float64(7), int64(6), object(9)
# memory usage: 1.2+ MB

# %% [markdown]
# ## issues
# - change year to date
# - bt_score to category
# - dubios to category
# - release_date to date
# - parse cast and crew
# - delete cast and crew gender columns since they are found in cast/crew json

# %%
movies_df.describe()
# Out:
#         Unnamed: 0         year     bt_score      dubious        imdbid  \
# count  7279.000000  7279.000000  7279.000000  7279.000000  7.279000e+03
# mean   3818.383294  1994.332051     2.106745     0.090809  9.139360e+05
# std    2203.194535    23.330282     1.097980     0.287357  1.175348e+06
# min       0.000000  1878.000000     0.000000     0.000000  1.000000e+00
# 25%    1920.500000  1985.000000     1.000000     0.000000  9.087300e+04
# 50%    3825.000000  2003.000000     3.000000     0.000000  3.324520e+05
# 75%    5695.500000  2011.000000     3.000000     0.000000  1.465051e+06
# max    7634.000000  2020.000000     3.000000     1.000000  6.536944e+06
#
#               tmdbId   popularity       revenue  vote_average    vote_count  \
# count    7279.000000  7279.000000  7.279000e+03   7279.000000   7279.000000
# mean    71338.645968    18.684234  5.756087e+07      6.545569   1402.759445
# std    101324.323243    38.012652  1.423315e+08      0.836113   2683.199152
# min         5.000000     0.600000  0.000000e+00      2.000000      1.000000
# 25%      9921.000000     6.194000  0.000000e+00      6.000000    108.000000
# 50%     25476.000000     9.041000  2.503829e+06      6.600000    400.000000
# 75%     77930.500000    17.318500  4.804042e+07      7.100000   1395.000000
# max    461615.000000  1608.867000  2.847246e+09      8.700000  31645.000000
#
#              budget  cast_female_representation  crew_female_representation
# count  7.279000e+03                 7279.000000                 7279.000000
# mean   1.812188e+07                   27.367160                   12.634757
# std    3.596806e+07                   15.307702                   12.344891
# min    0.000000e+00                    0.000000                    0.000000
# 25%    0.000000e+00                   16.196343                    4.347826
# 50%    1.500000e+06                   25.714286                   10.317460
# 75%    2.000000e+07                   36.666667                   17.647059
# max    3.800000e+08                  100.000000                  100.000000

# %%
movies_df.isnull().sum()
# Out:
# Unnamed: 0                    0
# title                         0
# year                          0
# bt_score                      0
# dubious                       0
# imdbid                        0
# tmdbId                        0
# genres                        0
# popularity                    0
# production_companies          0
# production_countries          0
# release_date                  0
# revenue                       0
# vote_average                  0
# vote_count                    0
# cast                          0
# crew                          0
# budget                        0
# cast_gender                   0
# crew_gender                   0
# cast_female_representation    0
# crew_female_representation    0
# dtype: int64

# %% [markdown]
# no null values in the movies dataset but we found nulls as [] and 0.0!

# %%
movies_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# no duplicates

# %%
movies_df.dtypes
# Out:
# Unnamed: 0                      int64
# title                          object
# year                            int64
# bt_score                        int64
# dubious                         int64
# imdbid                          int64
# tmdbId                          int64
# genres                         object
# popularity                    float64
# production_companies           object
# production_countries           object
# release_date                   object
# revenue                       float64
# vote_average                  float64
# vote_count                    float64
# cast                           object
# crew                           object
# budget                        float64
# cast_gender                    object
# crew_gender                    object
# cast_female_representation    float64
# crew_female_representation    float64
# dtype: object

# %%
movies_df['dubious'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# ## Oscar dataset assessment

# %%
oscar_df.shape
# Out:
# (5856, 6)

# %%
oscar_df.head()
# Out:
#    year        category                               film             name  \
# 0  1927  CINEMATOGRAPHY                  The Devil Dancer;    George Barnes
# 1  1927         WRITING  The Private Life of Helen of Troy     Gerald Duffy
# 2  1927         WRITING                         Underworld        Ben Hecht
# 3  1927         WRITING                   The Last Command       Lajos Biro
# 4  1927         WRITING                         7th Heaven  Benjamin Glazer
#
#       status gender
# 0  nominated   male
# 1  nominated   male
# 2     winner   male
# 3  nominated   male
# 4     winner   male

# %%
oscar_df.tail()
# Out:
#       year               category  \
# 5851  2021                WRITING
# 5852  2021         CINEMATOGRAPHY
# 5853  2021         COSTUME DESIGN
# 5854  2021  DOCUMENTARY (Feature)
# 5855  2021                WRITING
#
#                                                    film              name  \
# 5851                      The Worst Person in the World        Eskil Vogt
# 5852                               The Power of the Dog        Ari Wegner
# 5853                                            Cruella      Jenny Beavan
# 5854  Summer of Soul (...Or, When the Revolution Cou...  David Dinerstein
# 5855                      The Worst Person in the World     Joachim Trier
#
#          status  gender
# 5851  nominated    male
# 5852  nominated  female
# 5853     winner  female
# 5854     winner    male
# 5855  nominated    male

# %%
oscar_df.sample(5)
# Out:
#       year               category                       film  \
# 3652  1993                WRITING  In the Name of the Father
# 950   1950  DOCUMENTARY (Feature)           With These Hands
# 5312  2016  DOCUMENTARY (Feature)                       13th
# 2817  1979         CINEMATOGRAPHY              All That Jazz
# 3366  1989           BEST PICTURE            Field of Dreams
#
#                   name     status gender
# 3652      Jim Sheridan  nominated   male
# 950        Jack Arnold  nominated   male
# 5312   Spencer Averick  nominated   male
# 2817  Giuseppe Rotunno  nominated   male
# 3366   Lawrence Gordon  nominated   male

# %%
oscar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5856 entries, 0 to 5855
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      5856 non-null   int64
#  1   category  5856 non-null   object
#  2   film      5856 non-null   object
#  3   name      5856 non-null   object
#  4   status    5856 non-null   object
#  5   gender    5856 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 274.6+ KB

# %% [markdown]
# ## issues
# - category to category type
# - year to date
# - gender to category
# - status to category

# %%
oscar_df.describe()
# Out:
#               year
# count  5856.000000
# mean   1980.349214
# std      26.251848
# min    1927.000000
# 25%    1957.000000
# 50%    1981.000000
# 75%    2004.000000
# max    2021.000000

# %%
oscar_df.isnull().sum()
# Out:
# year        0
# category    0
# film        0
# name        0
# status      0
# gender      0
# dtype: int64

# %% [markdown]
# no null values in the oscar dataset

# %%
oscar_df.duplicated().sum()
# Out:
# 61

# %% [markdown]
# 61 duplicated values in the oscar dataset so we should drop them

# %%
oscar_df.dtypes
# Out:
# year         int64
# category    object
# film        object
# name        object
# status      object
# gender      object
# dtype: object

# %% [markdown]
# ## Movies df cleaning

# %%
# first drop unnamed index column
# movies_df.drop(labels='Unnamed', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 2
#       1 # first drop unnamed index column
# ----> 2 movies_df.drop(labels='Unnamed', inplace=True)
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Unnamed'] not found in axis"
